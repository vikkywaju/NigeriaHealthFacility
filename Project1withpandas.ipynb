# %%
import pandas as pd
project1=pd.read_csv("NMIS.csv")

# %%
project1
# Out:
#       maternal_health_delivery_services  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
# 5                                  True
# 6                                 False
# 7                                  True
# 8                                  True
# 9                                  True
# 10                                 True
# 11                                 True
# 12                                 True
# 13                                  NaN
# 14                                False
# 15                                False
# 16                                False
# 17                                False
# 18                                 True
# 19                                False
# 20                                 True
# 21                                 True
# ...

# %%
project1.head()# Display the head part of data
# Out:
#   maternal_health_delivery_services  \
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
#
#                          facility_type_display management  \
# 0                                  Health Post     public
# 1                  Primary Health Centre (PHC)    private
# 2  Basic Health Centre / Primary Health Clinic     public
# 3                  Primary Health Centre (PHC)     public
# 4                                  Health Post     public
#
#    emergency_transport skilled_birth_attendant phcn_electricity c_section_yn  \
# 0                 True                   False             True        False
# 1                 True                    True             True        False
# 2                 True                    True             True         True
# 3                False                   False            False        False
# ...

# %%
project1.tail()
# Out:
#       maternal_health_delivery_services  \
# 34134                              True
# 34135                              True
# 34136                             False
# 34137                             False
# 34138                             False
#
#                               facility_type_display management  \
# 34134                   Primary Health Centre (PHC)    private
# 34135  Basic Health Centre or Primary Health Clinic     public
# 34136                   Primary Health Centre (PHC)    private
# 34137                                    Dispensary     public
# 34138                   Primary Health Centre (PHC)     public
#
#        emergency_transport skilled_birth_attendant phcn_electricity  \
# 34134                 True                    True             True
# 34135                False                   False             True
# 34136                False                    True             True
# ...

# %%
project1.shape #no of rows and colums
# Out:
# (34139, 20)

# %%
project1.iloc[6:,]
# Out:
#       maternal_health_delivery_services  \
# 6                                 False
# 7                                  True
# 8                                  True
# 9                                  True
# 10                                 True
# 11                                 True
# 12                                 True
# 13                                  NaN
# 14                                False
# 15                                False
# 16                                False
# 17                                False
# 18                                 True
# 19                                False
# 20                                 True
# 21                                 True
# 22                                 True
# 23                                False
# 24                                 True
# 25                                 True
# 26                                 True
# 27                                 True
# ...

# %%
project1.iloc[1:5,:]
# Out:
#   maternal_health_delivery_services  \
# 1                              True
# 2                              True
# 3                              True
# 4                              True
#
#                          facility_type_display management  \
# 1                  Primary Health Centre (PHC)    private
# 2  Basic Health Centre / Primary Health Clinic     public
# 3                  Primary Health Centre (PHC)     public
# 4                                  Health Post     public
#
#    emergency_transport skilled_birth_attendant phcn_electricity c_section_yn  \
# 1                 True                    True             True        False
# 2                 True                    True             True         True
# 3                False                   False            False        False
# 4                False                   False            False        False
#
#   child_health_measles_immun_calc improved_water_supply improved_sanitation  \
# ...

# %%
project1.iloc[:,:]
# Out:
#       maternal_health_delivery_services  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
# 5                                  True
# 6                                 False
# 7                                  True
# 8                                  True
# 9                                  True
# 10                                 True
# 11                                 True
# 12                                 True
# 13                                  NaN
# 14                                False
# 15                                False
# 16                                False
# 17                                False
# 18                                 True
# 19                                False
# 20                                 True
# 21                                 True
# ...

# %% [markdown]
# We can specify column labels in the loc method to retrieve columns by label instead of by position

# %%
project1.loc[:5, "management"] #Retrieving the first five rows of the 'management' column
# Out:
# 0     public
# 1    private
# 2     public
# 3     public
# 4     public
# 5    private
# Name: management, dtype: object

# %%
project1.loc[5:,["facility_type_display","management"]]
# Out:
#                               facility_type_display   management
# 5                                       Health Post      private
# 6                                       Health Post       public
# 7                               Specialist Hospital      private
# 8                               Specialist Hospital      private
# 9                                       Health Post      private
# 10                                      Health Post       public
# 11                              Specialist Hospital      private
# 12                              Specialist Hospital      private
# 13                      Primary Health Centre (PHC)       public
# 14                                      Health Post       public
# 15                                       Dispensary       public
# 16                      Primary Health Centre (PHC)       public
# 17                                       Dispensary       public
# ...

# %% [markdown]
# # Filtering DataFrame

# %%
num_doctors_fulltime_filter=project1["num_doctors_fulltime"]<2

# %%
num_doctors_fulltime_filter
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
# 6         True
# 7        False
# 8        False
# 9         True
# 10        True
# 11        True
# 12       False
# 13       False
# 14       False
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22       False
# 23        True
# 24        True
# 25       False
# 26       False
# 27        True
# 28        True
# 29        True
#          ...
# 34109     True
# 34110     True
# 34111     True
# 34112     True
# 34113    False
# 34114     True
# 34115    False
# 34116     True
# 34117     True
# 34118    False
# 34119     True
# 34120     True
# 34121     True
# 34122     True
# 34123     True
# 34124     True
# 34125     True
# 34126     True
# 34127     True
# 34128    False
# 34129     True
# 34130     True
# 34131     True
# 34132     True
# 34133     True
# 34134     True
# 34135     True
# ...

# %%
facility_type_display_filter=(project1["num_doctors_fulltime"]>0) & (project1["facility_type_display"] =="Health Post")#create a filter
filtered_reviews=project1[facility_type_display_filter]#apply the filter on the review
filtered_reviews
# Out:
#       maternal_health_delivery_services facility_type_display management  \
# 5                                  True           Health Post    private
# 53                                False           Health Post     public
# 265                                True           Health Post    private
# 282                               False           Health Post    private
# 312                               False           Health Post     public
# 488                                True           Health Post    private
# 743                                True           Health Post     public
# 852                                True           Health Post     public
# 888                                True           Health Post    private
# 989                                True           Health Post    private
# 997                                True           Health Post    private
# 1148                              False           Health Post     public
# ...

# %%
management_filter=(project1["management"] =="public") & (project1["facility_type_display"]=="Primary Health Centre (PHC)")#create a filter
filtered_reviews=project1[management_filter]#apply the filter on the review
filtered_reviews
# Out:
#       maternal_health_delivery_services        facility_type_display  \
# 3                                  True  Primary Health Centre (PHC)
# 13                                  NaN  Primary Health Centre (PHC)
# 16                                False  Primary Health Centre (PHC)
# 18                                 True  Primary Health Centre (PHC)
# 24                                 True  Primary Health Centre (PHC)
# 27                                 True  Primary Health Centre (PHC)
# 33                                False  Primary Health Centre (PHC)
# 35                                 True  Primary Health Centre (PHC)
# 38                                 True  Primary Health Centre (PHC)
# 42                                 True  Primary Health Centre (PHC)
# 48                                False  Primary Health Centre (PHC)
# 49                                False  Primary Health Centre (PHC)
# 50                                 True  Primary Health Centre (PHC)
# ...

# %%
project1.dropna()
# Out:
#       maternal_health_delivery_services  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
# 5                                  True
# 6                                 False
# 7                                  True
# 9                                  True
# 10                                 True
# 11                                 True
# 12                                 True
# 15                                False
# 16                                False
# 17                                False
# 18                                 True
# 19                                False
# 20                                 True
# 21                                 True
# 23                                False
# 24                                 True
# 25                                 True
# ...

# %%
project1.
